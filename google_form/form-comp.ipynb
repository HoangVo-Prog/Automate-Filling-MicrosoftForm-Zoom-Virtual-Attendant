# %%
# !git clone https://github.com/HoangVo-Prog/Automate-Filling-MicrosoftForm-Zoom-Virtual-Attendant.git
# %cd Automate-Filling-MicrosoftForm-Zoom-Virtual-Attendant/google_form
# Out:
# Cloning into 'Automate-Filling-MicrosoftForm-Zoom-Virtual-Attendant'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 85 (delta 24), reused 70 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 43.39 KiB | 3.34 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# /kaggle/working/Automate-Filling-MicrosoftForm-Zoom-Virtual-Attendant/google_form

# %%
# !apt -y update
# !apt -y install wget unzip
# !wget -q https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !apt -y install ./google-chrome-stable_current_amd64.deb
# !pip install -q undetected-chromedriver==3.5.5
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.2 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,102 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]m
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# ...

# %%
# !python linux_run.py --source data/test.csv --form-url "https://docs.google.com/forms/d/e/xxx/viewform" --min-gap 30
# Out:
# ['Có', 'Trên 10 năm', '5', '5', '5', '4', '5', '3', '1', '2', '4', '5', '1', '4', '4', '4', '2', '5', '3', '5', '5', '4', '4', '4', '5', '4', '4', '5', '5', '4', '4', '5', '5', '5', '4', '5', '5', '5', 'Nam', 'Từ 31 tuổi đến 40 tuổi', 'Có', 'Không']
# Total questions found: 1
# Processing question index: 0 with value: Có
# Clicked option with value: Có
# Clicked Continue/Next button.
# Total questions found: 1
# Processing question index: 1 with value: Trên 10 năm
# Clicked option with value: Trên 10 năm
# Clicked Continue/Next button.
# Total questions found: 11
# Processing question index: 2 with value: 5
# Clicked option with value: 5
# Processing question index: 3 with value: 5
# Clicked option with value: 5
# Processing question index: 4 with value: 5
# Clicked option with value: 5
# Processing question index: 5 with value: 4
# Clicked option with value: 4
# Processing question index: 6 with value: 5
# Clicked option with value: 5
# Processing question index: 7 with value: 3
# ...
